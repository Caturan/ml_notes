# %% [markdown]
# ## Python Machine Learning (Sebastian Raschka & Vahid Mirjalili)

# %% [markdown]
# # The three different types of machine learning

# %% [markdown]
# - We will take a look at the three types of machine learning: supervised learning, unsupervised learning and reinforcement learning.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Making predictions about the future with supervised learning
# - The main goal in supervised learning is to learn a model from labeled training data that allows us to make predictions about unseen or future data.

# %% [markdown]
# ### Classification for predicting class labels
# - Classification is a subcategory of supervised learning where the goal is the predict the categorical class labels of new instances, based on past observations.
# - (email example: -spam/-nonspam)
# - Binary classification task, where the machine learning algorithm learns a set of rules in order to distinguish between two possible classes: spam and non-spam emails.

# %% [markdown]
# ### Regression for predicting continuous outcomes
# - Supervised learning, is the prediction of continous outcomes, which also called regression analysis.
# - In regression, we are given a number of predictor variables and a continuous response variable and we try to find a relationship between those variables that allows us to predict an outcome.
# - In the field of machin learning, the predictor variables are commonly called "features", and the response variables are usually referred to as "target variables".
# ![image.png](attachment:image.png)
# - Figure concept of linear regression. Given a feature variable x, and a target variable, y, we fit a straight line to this data that minimizes the distance-most commonly the average squared distance-between the data points and the fitted line.
# - We can now use the intercept and slope learned from this data to predict the target variable of new data.

# %% [markdown]
# ### Solving interactive problems with reinforcement learning
# - In reinforcement learning, the goal is to develop a system (agent) that improves its performance based on interactions with the environment.
# - Reinforcement learning as a field related to supervised learning.
# - An agent can then use reinforcement learning to learn a series of actions that maximizes this reward.
# - A popular examples of reinforcement learning is a chess engine.
# - A general scheme is that the agent in reinforcement learning tries to maximize the reinforcement learning tries to maximize the reward through a series of interactions with the environment.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Discovering hidden structures with unsupervised learning
# - Using unsupervised learning techniques, we are able to explore the structure of our data to extact meaningful information without the guidance of a known outcome variable or reward function.

# %% [markdown]
# ### Finding subgroups with clustering
# - Clustering is an exploratory data analysis technique that allows us to organize pile of information into meaningful subgroups (clusters) without having any prior knowladge of their group memberships.
# - Clustering is a great technique for structuring information and deriving meaningful relationships from data.

# %% [markdown]
# ### Dimensionality reduction for data compression
# - Another subfield of unsupervised learning is dimensionality reduction.
# - That can present a challenge for limited storage space and computational performance of machine learning alogrithms.
# - Unsupervised dimensionality reductions is a commonly used approach in feature preprocessing to remove noise from data, which can also degrade the predictive performance of certain algorithms, and compress the data onto a smaller dimensional subspace while retaining most of the relevant information.
# - Sometimes, dimensionality reduction can also be useful for visualizing data.
# ![image.png](attachment:image.png)

# %% [markdown]
# # Introduction to the basic terminology and notations
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Terminology
# - Training example: A row in a table representing the dataset and synonymous
# with an observation, record, instance, or sample (in most contexts, sample
# refers to a collection of training examples)
# - Training: Model fitting, for parametric models similar to parameter
# estimation.
# - Feature, abbrev. x: A column in a data table or data (design) matrix.
# Synonymous with predictor, variable, input, attribute, or covariate
# - Target, abbrev. y: Synonymous with outcome, output, response variable,
# dependent variable, (class) label, and ground truth.
# - Loss function: Often used synonymously with a cost function. Sometimes
# the loss function is also called an error function. In some literature, the
# term "loss" refers to the loss measured for a single data point, and the cost
# is a measurement that computes the loss (average or summed) over the
# entire dataset.

# %% [markdown]
# ## A roadmap for building machine learning systems
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Preprocessing - getting data into shape
# - Raw(çiğ) data rarely comes in the form and shpae that is necessary for the optimal performance of a learning algorithm.
# - Thus, the preprocessing of the data is one of the most crucial steps in any machine learning.
# - Dimensionality reduction can also improve the predictive performance of a model if the dataset contains a large number of irrelevant features (or noise); that is, if the dataset has a low signal-to-noise ratio.
# - Randomly divide the dataset into a seperate training and test dataset.
# - We use the training dataset to train and optimize our machine learning model, while we keep the test dataset until the very end to evaluate the final model.
